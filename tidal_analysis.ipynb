# %%
import sys
import os

#sys.path.append('/home/547/bxb547/ga-repository/agdc_statistics')
# print sys.path
LAT="--lat_range '(-12.01, -12.2113)'"
LON="--lon_range '(130.002, 130.20205)'" # 
YEAR="--year_range 2002-2010" # Requirement mandatory
PER="--per 25"  # DEFAULT percentage 10
SEASON="--season WINTER" # DEFAULT dummy meaning no season
EPOCH="--epoch 5"   # DEFAULT is 2
DEB="--debug True"   # DEFAULT is False
#%run tide_temporal.py --lon_range '(130.002, 130.20205)' --lat_range '(-12.01, -12.2113)'  --year_range 2002-2010 --per 25 --season WINTER --epoch 5 --debug True
# %run tide_temporal.py $LON $LAT $YEAR $PER $SEASON $EPOCH $DEB
# Out:
# Input date range 2002-2010
# running task for epoch 2002-01-01 TO 2006-12-31 on percentile 25 tide post  for lon/lat range (130.002, 130.20205)(-12.01, -12.2113) epoch 5 for season WINTER
#  doing for sensor ls5_nbar_albers
#  doing for sensor ls7_nbar_albers
#  epoch end date is reset for LS7 2003/03/01
#  doing for sensor ls8_nbar_albers
# reading from tidal model file and using Haversine algorithm to extract shortest distance
# Found tide post coordinates ('130.07', '-11.96', '-315', 17.109727448266856)
# received from predict tides  2016-12-14 15:17:29.228896
# ...

# %%
# %matplotlib inline
import matplotlib as mat
import matplotlib.pyplot as plt
print len(MY_DATA)
# cmap = mat.colors.ListedColormap(['b', '#ffcc66','#ffffcc' , '#ccff66' , '#2eb82e', '#009933' , '#006600'])
# bounds = [-1, 0, 0.1, 0.2, 0.3, 0.5, 0.8, 1]
# norm = mat.colors.BoundaryNorm(bounds, cmap.N)
for k in sorted(MY_DATA.iterkeys()):
    #my_data[k].plot(cmap=plt.cm.Blues, levels=8)
    # MY_DATA[k].green.plot(cmap=cmap, norm=norm)
    # plt.colors.BoundaryNorm(bounds, cmap.N)
    # MY_DATA[k].blue.plot() 
    plt.imshow(MY_DATA[k].blue, cmap='jet', aspect='auto') 
    plt.colorbar()
    plt.title('epoch-'+k)
    plt.ylabel('Y')
    plt.xlabel('X')
    plt.tight_layout()
    plt.show()
# Out:
# 4
